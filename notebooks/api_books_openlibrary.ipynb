# %%
import requests
import pandas as pd
import warnings

import json
from IPython.display import display, HTML
import time
import random

# %%
# ⚙️ Settings
pd.set_option('display.max_columns', None) # display all columns
warnings.filterwarnings('ignore') # ignore warnings

# %%
def get_books_by_subject(subject, limit=500, batch_size=10, delay=2):
   
    all_books = []
    failures = 0
    max_failures = 5
    
    for i in range(0, limit, batch_size):
        # Calculate offset
        offset = i
        
        # Adjust batch size for last request if needed
        current_batch_size = min(batch_size, limit - i)
        
        if current_batch_size <= 0:
            break
            
        print(f"Fetching books {offset+1}-{offset+current_batch_size} of {limit}...")
        
        # Use subject API
        formatted_subject = subject.replace(" ", "_").lower()
        endpoint = f"https://openlibrary.org/subjects/{formatted_subject}.json"
        params = {
            "limit": current_batch_size,
            "offset": offset
        }
        
        try:
            # Make the request with increased timeout
            response = requests.get(endpoint, params=params, timeout=30)
            
            if response.status_code == 200:
                data = response.json()
                
                books = data.get("works", [])
                all_books.extend(books)
                
                print(f"Retrieved {len(books)} books.")
                
                # Reset failure counter on success
                failures = 0
                
                # Check if we've reached the end of available books
                if len(books) < current_batch_size:
                    print(f"Only {len(books)} books available. Stopping.")
                    break
            else:
                failures += 1
                print(f"Error: {response.status_code}. Attempt {failures} of {max_failures}")
                
                if failures >= max_failures:
                    print("Too many consecutive failures. Stopping.")
                    break
                
                # Increase delay after failure
                time.sleep(delay * 2)
                continue
                
            # Respect rate limits
            print(f"Waiting {delay} second(s) before next request...")
            time.sleep(delay + random.uniform(0, 1))  # Add small random delay
            
        except Exception as e:
            failures += 1
            print(f"Exception: {type(e).__name__}: {str(e)}. Attempt {failures} of {max_failures}")
            
            if failures >= max_failures:
                print("Too many consecutive failures. Stopping.")
                break
                
            # Increase delay after failure
            time.sleep(delay * 3)
    
    print(f"Total books retrieved: {len(all_books)}")
    return all_books

list_of_columns = ['key', 'title', 'edition_count', 'cover_id', 'cover_edition_key', 'subject', 'ia_collection', 'printdisabled', 'lending_edition', 'lending_identifier', 'authors', 'first_publish_year', 'ia', 'public_scan', 'has_fulltext', 'availability']

# %%
# fiction_books = get_books_by_subject("fiction", limit=10000, batch_size=10, delay=2)

# %%
poetry_books = get_books_by_subject("poetry", limit=100, batch_size=10, delay=2)
# Out:
# Fetching books 1-10 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 11-20 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 21-30 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 31-40 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 41-50 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 51-60 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 61-70 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 71-80 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 81-90 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Fetching books 91-100 of 100...
# Retrieved 10 books.
# Waiting 2 second(s) before next request...
# Total books retrieved: 100

# %%
print(fiction_books[1]['subject'])
# Out:
# ['Alice (fictitious character : carroll), fiction', 'British and irish fiction (fictional works by one author)', 'Fiction, fantasy, general', 'JUVENILE FICTION', 'classics', 'Fantasy & Magic', 'Imagination & Play', 'adventure and adventurers', 'adventure and adventurers, fiction', 'adventure stories', 'adventure travel', 'animals', 'anthropomorphism', "artists' illustrated books", 'books and reading', 'child and youth fiction', 'children', "children's fiction", "children's literature", "children's literature, english", "children's stories", "children's stories, english", 'classic literature', 'coloring books', 'croquet', 'cuentos infantiles ingleses', 'curiosidad', 'curiosidad en los niños', 'curiosity', 'curiosity in children', 'english', 'english adventure stories', 'english fantastic fiction', 'english fantasy fiction', 'english fantasy literature', 'english language', 'english literature', 'english nonsense verses', 'fairy tales', 'fantasy', 'fantasy fiction', 'fantasy in fiction', 'fantasy  magic', 'fantasía', 'ficción juvenil', 'fiction', 'friendship', 'girls', 'girls, fiction', 'hookahs', 'humor', 'humorous stories', 'illustrations', 'imaginary places', 'juvenile literature', 'legends', 'literary nonsense', 'logic', 'lugares imaginarios', 'mythical animals', 'niñas', 'nonsense verses', 'novela', 'novela fantástica', 'novela juvenil', 'open library staff picks', 'picture books', 'playing cards', 'rabbits', 'readers', 'reading materials', 'short novel', 'tea', 'texts', 'Alice (Fictitious character : Carroll)', 'English language, textbooks for foreign speakers', 'Fantastique', 'Enfants', 'Affirmation de soi', 'Spanish language materials', 'Alicia (Personaje literario : Carroll)', 'Spanish language', 'nyt:chapter-books=2010-02-21', 'New York Times bestseller', 'Literatura infanto-juvenil', 'Literatura inglesa', 'Carroll, lewis, 1832-1898', "Children's literature, history and criticism", 'Children, books and reading', 'Crocheting', 'Fiction, general', 'Fantasy fiction, history and criticism', 'Toy and movable books', 'Imagination', 'Textbooks for foreign speakers', 'Readers for new literates', 'High interest-low vocabulary books', 'Science fiction', 'CUENTO INFANTIL INGLES', 'History and criticism', 'Translations into Irish', 'Irish literature', 'Swahili language', 'Ficc ʹa o (ge nero)', 'Shi jie wen xue', 'Xiao shuo', 'Fantasi a', 'Tong hua', 'Suo xie', 'Shao er du wu', 'Pin yin du wu', "Children's stories, Chinese", 'Chinese language', 'Translations into Polish', 'Ying yu', 'Yu yan du wu', 'Decision making', 'Juvenile Wit and humor', 'Conduct of life', 'Illusion (Philosophy)', 'Innocence (Psychology)', 'Dreams', 'Courts and courtiers', 'Theft', 'Courts', 'Curiosité', 'Romans, nouvelles, etc. pour la jeunesse', 'Prise de décision', 'Humour pour la jeunesse', 'Morale pratique', 'Lieux imaginaires', 'Illusion (Philosophie)', 'Rêves', 'Cartes à jouer', 'Cours et courtisans', 'Croquet (Jeu)', 'Vol (Droit)', 'Tribunaux', 'Histoires pour enfants anglaises', 'Literature, collections', 'Fiction, short stories (single author)', 'Contes de fées', 'English fiction', 'Translations into Ladino', 'Nonsense literature', 'Fantasmes', 'Dinosaurier', 'Utdöda djur', 'Urtidsdjur', 'Forntiden', 'Geologi', 'Evolution', 'Jorden', 'Fantastiske fortællinger', 'Translations into Yiddish', 'Criticism and interpretation', 'History', "Alice's adventures in Wonderland (Carroll, Lewis)", 'Alice in Wonderland;', 'North', 'Rural-urban migration', 'Russian language']

# %%
fiction_df = pd.DataFrame(fiction_books)

# %%
display(fiction_df.head(20))
fiction_df.to_csv("../data/raw/openlibrary_fiction_10k.csv", index=False)
# Out:
#                   key                                  title  edition_count  \
# 0     /works/OL66554W                    Pride and Prejudice           4035
# 1    /works/OL138052W       Alice's Adventures in Wonderland           3546
# 2     /works/OL21177W                      Wuthering Heights           2850
# 3   /works/OL8193497W                      A Christmas Carol           2727
# 4     /works/OL53908W         Adventures of Huckleberry Finn           2552
# 5   /works/OL8193416W             The Picture of Dorian Gray           2297
# 6     /works/OL66513W                                   Emma           2260
# 7   /works/OL8193478W                           Oliver Twist           2210
# 8    /works/OL450063W  Frankenstein or The Modern Prometheus           2183
# 9   /works/OL8193465W                   A Tale of Two Cities           2059
# 10    /works/OL18417W             The Wonderful Wizard of Oz           2052
# 11    /works/OL66562W                  Sense and Sensibility           2015
# 12    /works/OL24034W                        Treasure Island           1984
# 13    /works/OL29983W                           Little Women           1887
# 14    /works/OL20600W                     Gulliver's Travels           1809
# 15   /works/OL503666W                            Don Quixote           1587
# 16  /works/OL8721462W                     Great Expectations           1493
# 17   /works/OL262496W                     A Study in Scarlet           1444
# 18   /works/OL244537W                         The Art of War           1432
# 19  /works/OL1089297W                             The Prince           1406
#
#       cover_id cover_edition_key  \
# 0   14348537.0       OL47044678M
# 1   10527843.0       OL31754751M
# 2   12818862.0       OL38586477M
# 3   13299222.0              None
# 4    8157718.0        OL7062714M
# 5   14314858.0              None
# 6    9278312.0       OL13573615M
# 7   13300802.0              None
# 8   12356249.0       OL35649409M
# 9   13301713.0              None
# 10    552443.0        OL8155451M
# 11   9278292.0       OL14041582M
# 12  13859660.0       OL40812029M
# 13   8775559.0       OL27300715M
# 14  12717083.0       OL26445784M
# 15  14428305.0              None
# 16  13322313.0       OL45791004M
# 17  13405534.0       OL47068254M
# 18   4849549.0        OL8784104M
# 19  12726168.0       OL37826838M
#
#                                               subject  \
# 0   [Fiction, Romance, Historical, Regency, Britis...
# 1   [Alice (fictitious character : carroll), ficti...
# 2   [British and irish fiction (fictional works by...
# 3   [Ghost stories, Readers, Ebenzer Scrooge (Fict...
# 4   [adventure and adventurers, Adventure stories,...
# 5   [British and irish fiction (fictional works by...
# 6   [Social life and customs, Mate selection, Fict...
# 7   [Bildungsromans, Boys, Brigands and robbers, B...
# 8   [Frankenstein (Fictitious character), Frankens...
# 9   [British, British and irish fiction (fictional...
# 10  [Witches, Toy and movable books, Spanish langu...
# 11  [Fiction, Romance, Historical, Regency, Inheri...
# 12  [Fiction, Treasure Island (Imaginary place), T...
# 13  [Romans, Jeunes filles, Soeurs, Sisters, Young...
# 14  [YA, Young adult, Juvenile, Fiction, Fantasy, ...
# 15  [Don Quixote (Cervantes Saavedra, Miguel de), ...
# 16  [Authors, Benefactors, Bildungsromans, Boys, B...
# 17  [Action & Adventure Fiction, aortic aneurysm, ...
# 18  [Open Library Staff Picks, Early works to 1800...
# 19  [Political science, early works to 1800, Machi...
#
#                                         ia_collection  printdisabled  \
# 0   [365-Books-by-Women-Authors, additional_collec...           True
# 1   [Boston_College_Library, additional_collection...           True
# 2   [365-Books-by-Women-Authors, JaiGyan, Servants...           True
# 3   [additional_collections, americana, aozorabunk...           True
# 4   [additional_collections, album_recordings, ame...           True
# 5   [additional_collections, americana, americanun...           True
# 6   [California-State-Suggested-Reading, additiona...           True
# 7   [Princeton, americana, audio_bookspoetry, beth...           True
# 8   [additional_collections, americana, americanun...           True
# 9   [ColumbiaUniversityLibraries, JaiGyan, america...           True
# 10  [americana, americanuniversity-ol, bannedbooks...           True
# 11  [JaiGyan, ServantsOfKnowledge, ServantsOfKnowl...           True
# 12  [YorkUniversity, americana, bpljordan-ol, brig...           True
# 13  [additional_collections, americana, aozorabunk...           True
# 14  [California-State-Suggested-Reading, additiona...           True
# 15  [JohnCarterBrownLibrary, Princeton, additional...           True
# 16  [California-State-Suggested-Reading, additiona...           True
# 17  [additional_collections, americana, audio_book...           True
# 18  [americana, americanuniversity-ol, belmont-ol,...           True
# 19  [americana, americanuniversity-ol, barryuniver...           True
#
#    lending_edition             lending_identifier  \
# 0      OL50444320M                 bwb_KS-179-237
# 1      OL45637056M  alicesadventures0000unse_v7d2
# 2      OL57648863M       wutheringheights0000kesh
# 3      OL50494370M         christmascarol00dick_7
# 4      OL48061167M  adventuresofhuck0000mark_f4w4
# 5      OL25669538M         temunatdoryangri008800
# 6      OL50293425M             isbn_9781905716890
# 7      OL46835116M       olivertwist0000char_v6j2
# 8      OL26683337M       frankensteinormo00shel_8
# 9      OL25709295M           a-tale-of-two-cities
# 10      OL7241696M            newwizardofoz00baum
# 11     OL47010286M       sensesensibility00aust_8
# 12     OL38627923M    treasureisland0000unse_k0j8
# 13     OL21516677M       littlewomen0000alco_t3z5
# 14     OL33225067M         voyagesdegullive00swif
# 15     OL24343614M       elingeniosohidal00cervrs
# 16     OL13535641M              dickenswork14dick
# 17     OL47067961M    crime_etrange_2206_librivox
# 18      OL7101974M     artofwaroldestmi00suntuoft
# 19      OL7035430M          machiavelli00machuoft
#
#                                               authors  first_publish_year  \
# 0   [{'key': '/authors/OL21594A', 'name': 'Jane Au...                1813
# 1   [{'key': '/authors/OL22098A', 'name': 'Lewis C...                1865
# 2   [{'key': '/authors/OL24529A', 'name': 'Emily B...                1846
# 3   [{'key': '/authors/OL24638A', 'name': 'Charles...                1843
# 4   [{'key': '/authors/OL18319A', 'name': 'Mark Tw...                1876
# 5   [{'key': '/authors/OL20646A', 'name': 'Oscar W...                1890
# 6   [{'key': '/authors/OL21594A', 'name': 'Jane Au...                1815
# 7   [{'key': '/authors/OL24638A', 'name': 'Charles...                1822
# 8   [{'key': '/authors/OL25342A', 'name': 'Mary Sh...                1818
# 9   [{'key': '/authors/OL24638A', 'name': 'Charles...                1800
# 10  [{'key': '/authors/OL23431A', 'name': 'L. Fran...                1899
# 11  [{'key': '/authors/OL21594A', 'name': 'Jane Au...                1811
# 12  [{'key': '/authors/OL25963A', 'name': 'Robert ...                1880
# 13  [{'key': '/authors/OL26680A', 'name': 'Louisa ...                1848
# 14  [{'key': '/authors/OL24522A', 'name': 'Jonatha...                1726
# 15  [{'key': '/authors/OL66452A', 'name': 'Miguel ...                1600
# 16  [{'key': '/authors/OL24638A', 'name': 'Charles...                1861
# 17  [{'key': '/authors/OL161167A', 'name': 'Arthur...                1887
# 18       [{'key': '/authors/OL30553A', 'name': '孙武'}]                1900
# 19  [{'key': '/authors/OL23135A', 'name': 'Niccolò...                1515
#
#                                ia  public_scan  has_fulltext  \
# 0                  bwb_KS-179-237         True          True
# 1   alicesadventures0000unse_v7d2         True          True
# 2        wutheringheights0000kesh         True          True
# 3          christmascarol00dick_7         True          True
# 4   adventuresofhuck0000mark_f4w4         True          True
# 5          temunatdoryangri008800         True          True
# 6              isbn_9781905716890         True          True
# 7        olivertwist0000char_v6j2         True          True
# 8        frankensteinormo00shel_8         True          True
# 9            a-tale-of-two-cities         True          True
# 10            newwizardofoz00baum         True          True
# 11       sensesensibility00aust_8         True          True
# 12    treasureisland0000unse_k0j8         True          True
# 13       littlewomen0000alco_t3z5         True          True
# 14         voyagesdegullive00swif         True          True
# 15       elingeniosohidal00cervrs         True          True
# 16              dickenswork14dick         True          True
# 17    crime_etrange_2206_librivox         True          True
# 18     artofwaroldestmi00suntuoft         True          True
# 19          machiavelli00machuoft         True          True
#
#                                          availability
# 0   {'status': 'open', 'available_to_browse': Fals...
# 1   {'status': 'open', 'available_to_browse': Fals...
# 2   {'status': 'open', 'available_to_browse': Fals...
# 3   {'status': 'open', 'available_to_browse': Fals...
# 4   {'status': 'open', 'available_to_browse': Fals...
# 5   {'status': 'open', 'available_to_browse': Fals...
# 6   {'status': 'open', 'available_to_browse': Fals...
# 7   {'status': 'open', 'available_to_browse': Fals...
# 8   {'status': 'open', 'available_to_browse': Fals...
# 9   {'status': 'open', 'available_to_browse': Fals...
# 10  {'status': 'open', 'available_to_browse': Fals...
# 11  {'status': 'open', 'available_to_browse': Fals...
# 12  {'status': 'open', 'available_to_browse': Fals...
# 13  {'status': 'open', 'available_to_browse': Fals...
# 14  {'status': 'open', 'available_to_browse': Fals...
# 15  {'status': 'open', 'available_to_browse': Fals...
# 16  {'status': 'open', 'available_to_browse': Fals...
# 17                                                NaN
# 18  {'status': 'open', 'available_to_browse': Fals...
# 19  {'status': 'open', 'available_to_browse': Fals...
